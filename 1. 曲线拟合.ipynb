# %%
import numpy as np
x = np.random.rand(100).astype(np.float32)
y = 3*x*x+1

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(x,y,'ro')
plt.show()

# %%
import tensorflow as tf
w1 = tf.Variable(tf.random_uniform([1],-1.0,1.0))
w2 = tf.Variable(tf.random_uniform([1],-1.0,1.0))
w3 = tf.Variable(tf.random_uniform([1],-1.0,1.0))
b = tf.Variable(tf.zeros([1]))
y_ = w1*x+w2*x*x+w3*x*x*x+b
loss = tf.reduce_mean(tf.square(y - y_))
optimizer = tf.train.GradientDescentOptimizer(0.5)
train = optimizer.minimize(loss)
init = tf.global_variables_initializer()

session = tf.Session()
session.run(init)
for step in range(50):
   session.run(train)
print(step, session.run(w1),session.run(w2),session.run(w3),session.run(b))
# Out:
# 49 [0.6145031] [1.3627299] [1.1240803] [0.953895]

# %%
plt.plot(x,y,'ro')
y__ = session.run(w1)*x+session.run(w2)*x*x+session.run(w3)*x*x*x+session.run(b)
order = np.argsort(x)
xs = np.array(x)[order]
ys = np.array(y__)[order]
plt.plot(xs,ys)
plt.show()
